# %% [markdown]
# <a href="https://colab.research.google.com/github/jkingok/Complete-Python-3-Bootcamp/blob/answers/17-Advanced%20Python%20Objects%20and%20Data%20Structures/06-Advanced%20Python%20Objects%20Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Python Objects Test

# %% [markdown]
# ## Advanced Numbers
#
# **Problem 1: Convert 1024 to binary and hexadecimal representation**

# %%
bin(1024), hex(1024)
# Out:
# ('0b10000000000', '0x400')

# %% [markdown]
# **Problem 2: Round 5.23222 to two decimal places**

# %%
round(5.23222, 2)
# Out:
# 5.23

# %% [markdown]
# ## Advanced Strings
# **Problem 3: Check if every letter in the string s is lower case**

# %%
s = 'hello how are you Mary, are you feeling okay?'

s.islower()
# Out:
# False

# %% [markdown]
# **Problem 4: How many times does the letter 'w' show up in the string below?**

# %%
s = 'twywywtwywbwhsjhwuwshshwuwwwjdjdid'

s.count('w')
# Out:
# 12

# %% [markdown]
# ## Advanced Sets
# **Problem 5: Find the elements in set1 that are not in set2:**

# %%
set1 = {2,3,1,5,6,8}
set2 = {3,1,7,5,6,8}

set1 - set2
# Out:
# {2}

# %% [markdown]
# **Problem 6: Find all elements that are in either set:**

# %% [markdown]
# ## Advanced Dictionaries
#
# **Problem 7: Create this dictionary:
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64}
#  using a dictionary comprehension.**

# %%
{n: n**3 for n in range(5)}
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64}

# %% [markdown]
# ## Advanced Lists
#
# **Problem 8: Reverse the list below:**

# %%
list1 = [1,2,3,4]
list(reversed(list1))
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# **Problem 9: Sort the list below:**

# %%
list2 = [3,4,2,5,1]
sorted(list2)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Great Job!
