# %% [markdown]
# <a href="https://colab.research.google.com/github/jkingok/Complete-Python-3-Bootcamp/blob/answers/15-PDFs-and-Spreadsheets/02-PDFs-Spreadsheets-Puzzle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='https://github.com/jkingok/Complete-Python-3-Bootcamp/blob/answers/Pierian_Data_Logo.png?raw=1'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # PDFs and Spreadsheets Puzzle Exercise
#
# Let's test your skills, the files needed for this puzzle exercise
#
# You will need to work with two files for this exercise and solve the following tasks:
#
# * Task One: Use Python to extract the Google Drive link from the .csv file. (Hint: Its along the diagonal from top left to bottom right).
# * Task Two: Download the PDF from the Google Drive link (we already downloaded it for you just in case you can't download from Google Drive) and find the phone number that is in the document. Note: There are different ways of formatting a phone number!

# %% [markdown]
# ## Task One: Grab the Google Drive Link from .csv File

# %%
import csv

# %%
with open('find_the_link.csv', 'r', encoding='utf-8') as f:
  csv_data = csv.reader(f)
  data_lines = list(csv_data)
  url = ''.join([line[i] for i, line in enumerate(data_lines)])
print(url)
# Out:
# https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q

# %%
# THe correct result is shown below, if you can't download from Google Drive,
# we added the PDF file to the Exercise_Files folder already
# Out:
# 'https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q'

# %% [markdown]
# ## Task Two: Download the PDF from the Google Drive link and find the phone number that is in the document.

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import pypdf
import re

# %%
with open('Find_the_Phone_Number.pdf', 'rb') as f:
  pdf_reader = pypdf.PdfReader(f)
  for i, page in enumerate(pdf_reader.pages):
    print(f"Page {i + 1}: {re.findall(r'\d{3}.\d{3}.\d{4}', page.extract_text())}")
# Out:
# Page 1: []
# Page 2: []
# Page 3: []
# Page 4: []
# Page 5: []
# Page 6: []
# Page 7: []
# Page 8: []
# Page 9: []
# Page 10: []
# Page 11: []
# Page 12: []
# Page 13: []
# Page 14: ['505.503.4455']
# Page 15: []
# Page 16: []
# Page 17: []

# %%
# You should get this phone number
# 505 503 4455
